# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !git clone https://github.com/ultralytics/ultralytics.git

# %%
# %cd /content/ultralytics

# %%
# !pip install -r requirements.txt

# %%
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.25 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.6/78.2 GB disk)

# %%
# !gdown https://drive.google.com/uc?id=1eTD-V5A1-ZGS3Rr-syip8kdZfWKRXHDP
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1eTD-V5A1-ZGS3Rr-syip8kdZfWKRXHDP
# To: /content/ultralytics/test2.mp4
# 100% 2.38M/2.38M [00:00<00:00, 122MB/s]

# %%
# %cd /content/ultralytics

# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source="/content/ultralytics/test2.mp4"
# Out:
# /content/ultralytics
# ...
# 100% 6.23M/6.23M [00:00<00:00, 72.6MB/s]
# Ultralytics YOLOv8.0.25 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# video 1/1 (1/229) /content/ultralytics/test2.mp4: 384x640 19 persons, 1 car, 1 traffic light, 14.2ms
# video 1/1 (2/229) /content/ultralytics/test2.mp4: 384x640 13 persons, 1 car, 2 traffic lights, 8.4ms
# video 1/1 (3/229) /content/ultralytics/test2.mp4: 384x640 14 persons, 1 car, 2 traffic lights, 9.2ms
# video 1/1 (4/229) /content/ultralytics/test2.mp4: 384x640 15 persons, 2 cars, 2 traffic lights, 8.4ms
# video 1/1 (5/229) /content/ultralytics/test2.mp4: 384x640 14 persons, 2 cars, 2 traffic lights, 2 handbags, 9.1ms
# video 1/1 (6/229) /content/ultralytics/test2.mp4: 384x640 10 persons, 4 cars, 2 traffic lights, 2 handbags, 8.5ms
# ...

# %% [markdown]
# ### Custom Dataset

# %%
# !yolo task=detect mode=train model=yolov8n.pt data="/content/drive/MyDrive/Yapay_Zeka/YOLOv8/data/data.yaml" epochs=15 imgsz=640
# Out:
# Ultralytics YOLOv8.0.25 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/ultralytics/runs/detect/train/weights/best.pt data=/content/drive/MyDrive/Yapay_Zeka/YOLOv8/data/data.yaml
# Out:
# Ultralytics YOLOv8.0.25 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/drive/MyDrive/Yapay_Zeka/YOLOv8/data/val/labels.cache... 65 images, 0 backgrounds, 0 corrupt: 100% 65/65 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:02<00:00,  1.87it/s]
#                    all         65         77      0.858      0.832      0.878      0.464
#                  drone         65         31      0.904      0.839      0.912      0.544
#                    kuş         65         46      0.811      0.826      0.844      0.384
# Speed: 3.0ms pre-process, 4.2ms inference, 0.0ms loss, 2.2ms post-process per image

# %%
# !yolo task=detect mode=predict model=/content/ultralytics/runs/detect/train/weights/best.pt conf=0.25 source="/content/drive/MyDrive/Yapay_Zeka/YOLOv8/p.jpg"
# Out:
# Ultralytics YOLOv8.0.25 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Yapay_Zeka/YOLOv8/p.jpg: 576x640 5 kuşs, 14.1ms
# Speed: 0.7ms pre-process, 14.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/ultralytics/runs/detect/predict6

# %%
# !yolo task=detect mode=predict model=/content/ultralytics/runs/detect/train/weights/best.pt conf=0.50 source="/content/drive/MyDrive/Yapay_Zeka/YOLOv7/yolov7/w.mp4"
# Out:
# Ultralytics YOLOv8.0.25 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Model summary (fused): 168 layers, 3006038 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (1/1075) /content/drive/MyDrive/Yapay_Zeka/YOLOv7/yolov7/w.mp4: 384x640 1 drone, 13.6ms
# video 1/1 (2/1075) /content/drive/MyDrive/Yapay_Zeka/YOLOv7/yolov7/w.mp4: 384x640 1 drone, 9.5ms
# video 1/1 (3/1075) /content/drive/MyDrive/Yapay_Zeka/YOLOv7/yolov7/w.mp4: 384x640 1 drone, 9.6ms
# video 1/1 (4/1075) /content/drive/MyDrive/Yapay_Zeka/YOLOv7/yolov7/w.mp4: 384x640 1 drone, 10.5ms
# video 1/1 (5/1075) /content/drive/MyDrive/Yapay_Zeka/YOLOv7/yolov7/w.mp4: 384x640 1 drone, 8.7ms
# video 1/1 (6/1075) /content/drive/MyDrive/Yapay_Zeka/YOLOv7/yolov7/w.mp4: 384x640 1 drone, 8.9ms
# video 1/1 (7/1075) /content/drive/MyDrive/Yapay_Zeka/YOLOv7/yolov7/w.mp4: 384x640 1 drone, 11.4ms
# video 1/1 (8/1075) /content/drive/MyDrive/Yapay_Zeka/YOLOv7/yolov7/w.mp4: 384x640 1 drone, 9.7ms
# ...

# %%
from IPython.display import display, Image

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.25 🚀 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 23.9/78.2 GB disk)

# %%
Image(filename='/content/ultralytics/runs/detect/train/confusion_matrix.png', width=600)

# %%
# %cd {HOME}
Image(filename='/content/ultralytics/runs/detect/train/results.png', width=600)
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/ultralytics

# %%
# %cd {HOME}
Image(filename='/content/ultralytics/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content/ultralytics
